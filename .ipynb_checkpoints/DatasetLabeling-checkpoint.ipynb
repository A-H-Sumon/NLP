# %%
import pandas as pd
dir = "F:\Rs\FinalDataset.xlsx"
df = pd.read_excel(dir)
df.head(10)
# Out:
#                                           clean_text
# 0                    last tweet alone room want die
# 1   winding want say im permanently leaving drama...
# 2                                           want die
# 3                               nvm mi nuff want die
# 4                                           want die
# 5                     since saying want die say much
# 6  iam incredibly drunk sxn feel like shot want f...
# 7  fun fun im mad thought id be want die dont car...
# 8   bts different every group exists love fucking...
# 9  happy new year first happy birthday kun nct mu...

# %%
#!pip install textblob
#from textblob import TextBlob

# %%
from textblob import TextBlob

# %%
df_copy = df

for f in df['clean_text']:
    for i in f:
        dff = TextBlob(f).sentiment.polarity
        df_copy['label'] = dff(i)

df = df_copy
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14344/256341973.py in <module>
#       4     for i in f:
#       5         dff = TextBlob(f).sentiment.polarity
# ----> 6         df_copy['label'] = dff(i)
#       7
#       8 df = df_copy
#
# TypeError: 'float' object is not callable

# %%
df.head(10)
# Out:
#                                            clean_text  label
# 0                     last tweet alone room want die    0.25
# 1    winding want say im permanently leaving drama...   0.25
# 2                                            want die   0.25
# 3                                nvm mi nuff want die   0.25
# 4                                            want die   0.25
# 5                      since saying want die say much   0.25
# 6   iam incredibly drunk sxn feel like shot want f...   0.25
# 7   fun fun im mad thought id be want die dont car...   0.25
# 8    bts different every group exists love fucking...   0.25
# 9   happy new year first happy birthday kun nct mu...   0.25
# 10                                          want die    0.25
# 11                                minutes un want die   0.25
# 12                              harry pretty want die   0.25
# 13  job cancelling nye event vax test requirement ...   0.25
# ...

# %%
for i in df['label']
    df= TextBlob(f).sentiment.polarity
    #df['label']=print(f'{result}')
# Out:
# 0.25
